# %%
import urllib
import json                 # Used to load data into JSON format
from pprint import pprint   # pretty-print

# %%
url = "https://aoe2.net/api/leaderboard?game=aoe2de&leaderboard_id=3&start=22128&count=10000"
response = urllib.request.urlopen(url)
print(response)
# Just an object:   <http.client.HTTPResponse at 0x7f2618123e10>

# %%
text = response.read()

# %%
json_data = json.loads(text)

# %%
import pandas as pd

# %%
df1=pd.DataFrame(data=json_data['leaderboard'], index = df1['rank'])
df1.head()
# Out:
#        clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 22128  None    None      0     94          1092.0             5.0  None
# 22129  None    None      0     12           994.0            -1.0  None
# 22130  DSGG    None      0     10           931.0            -1.0  None
# 22131  Seek    None      0     27          1065.0             2.0  None
# 22132  None    None      1     22          1053.0             2.0  None
#
#        last_match  last_match_time  losses  lowest_streak  \
# rank
# 22128  1588863833       1588863833      49           -8.0
# 22129  1587493352       1587493352       8           -3.0
# 22130  1588195276       1588195276       6           -1.0
# 22131  1588878229       1588878229      16           -6.0
# 22132  1587132821       1587132821      13           -6.0
#
#                       name  previous_rating  profile_id   rank  rating  \
# rank
# 22128  eXzopioN [Ballon1$]            915.0     1494125  22128     931
# ...

# %%
url = "https://aoe2.net/api/leaderboard?game=aoe2de&leaderboard_id=3&start=12128&count=10000"
response = urllib.request.urlopen(url)
print(response)
# Just an object:   <http.client.HTTPResponse at 0x7f2618123e10>
text = response.read()
json_data = json.loads(text)

# %%
df2=pd.DataFrame(data=json_data['leaderboard'],index = df2['rank'])
df2.head()
# Out:
#        clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 12128   icu    None      3    128            1156              11  None
# 12129   Pav    None      2     17            1175               3  None
# 12130  None    None      5    259            1178               6  None
# 12131  None    None      5     72            1183               4  None
# 12132  None    None     16    167            1084               7  None
#
#        last_match  last_match_time  losses  lowest_streak         name  \
# rank
# 12128  1588791067       1588791067      62             -5         Twix
# 12129  1588793588       1588793588       8             -4       Gethvi
# 12130  1588409999       1588409999     127             -5      Pantera
# 12131  1587085711       1587085711      37             -5  Elbereth_01
# 12132  1588791238       1588791238      80             -4       Garc99
#
#        previous_rating  profile_id   rank  rating           steam_id  streak  \
# rank
# ...

# %%
url = "https://aoe2.net/api/leaderboard?game=aoe2de&leaderboard_id=3&start=2128&count=10000"
response = urllib.request.urlopen(url)
print(response)
# Just an object:   <http.client.HTTPResponse at 0x7f2618123e10>
text = response.read()
json_data = json.loads(text)

# %%
df3=pd.DataFrame(data=json_data['leaderboard'], index = df3['rank'])
df3.head()
# Out:
#        clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 12128  None    None      1    367          1446.0             7.0  None
# 12129  None    None      1    168          1371.0             5.0  None
# 12130  None    None      1     95          1435.0             5.0  None
# 12131  None    None      0     17          1371.0             4.0  None
# 12132  None    None      2     55          1392.0             7.0  None
#
#        last_match  last_match_time  losses  lowest_streak          name  \
# rank
# 12128  1588883657       1588883657     175           -6.0   J4MMYD0D93R
# 12129  1587567820       1587567820      76           -7.0  simon_nelson
# 12130  1588891849       1588891849      47           -4.0     cocukadam
# 12131  1587328120       1587328120      11          -10.0  Deadbeat Dan
# 12132  1588829259       1588829259      20           -2.0      MEOWBOSS
#
#        previous_rating  profile_id  rank  rating           steam_id  streak  \
# rank
# ...

# %%
url = "https://aoe2.net/api/leaderboard?game=aoe2de&leaderboard_id=3&start=1&count=2128"
response = urllib.request.urlopen(url)
print(response)
# Just an object:   <http.client.HTTPResponse at 0x7f2618123e10>
text = response.read()
json_data = json.loads(text)

# %%
df4=pd.DataFrame(data=json_data['leaderboard'],index = df4['rank'])
df4.head()
# Out:
#       clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 1     None    None      1    379            2321              19  None
# 2     None    None     80   1073            2261              17  None
# 3     None    None     13    435            2233              32  None
# 4     None    None      5    455            2295              19  None
# 5     None    None      2    546            2198              11  None
#
#       last_match  last_match_time  losses  lowest_streak            name  \
# rank
# 1     1588793897       1588793897     110             -5        TheViper
# 2     1588907728       1588907728     334             -6      [aM]MbL40C
# 3     1588302652       1588302652     103             -4  Heresy | dogao
# 4     1588856609       1588856609     109             -4           Nicov
# 5     1588875805       1588875805     205             -5         Villese
#
#       previous_rating  profile_id  rank  rating           steam_id  streak  \
# rank
# ...

# %%
df4.tail()
# Out:
#       clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 2124  AYRE    None      1     20            1371               5  None
# 2125  None    None      0     28            1404               8  None
# 2126  None    None      0     21            1371               6  None
# 2127   HKG    None     10    641            1406               9  None
# 2128  None    None      1    367            1446               7  None
#
#       last_match  last_match_time  losses  lowest_streak                name  \
# rank
# 2124  1586651680       1586651680       5             -2           [AYRE]Azu
# 2125  1588692562       1588692562       8             -2  Ne Demek Pilav Yok
# 2126  1588096801       1588096801       5             -2              Malice
# 2127  1588855858       1588855858     306             -7             Supreme
# 2128  1588883657       1588883657     175             -6         J4MMYD0D93R
#
# ...

# %%
frames = [df4,df3,df2,df1]
leaderboard = pd.concat(frames)

# %%
leaderboard.head()
# Out:
#       clan country  drops  games  highest_rating  highest_streak  icon  \
# rank
# 1     None    None      1    379          2321.0            19.0  None
# 2     None    None     80   1073          2261.0            17.0  None
# 3     None    None     13    435          2233.0            32.0  None
# 4     None    None      5    455          2295.0            19.0  None
# 5     None    None      2    546          2198.0            11.0  None
#
#       last_match  last_match_time  losses  lowest_streak            name  \
# rank
# 1     1588793897       1588793897     110           -5.0        TheViper
# 2     1588907728       1588907728     334           -6.0      [aM]MbL40C
# 3     1588302652       1588302652     103           -4.0  Heresy | dogao
# 4     1588856609       1588856609     109           -4.0           Nicov
# 5     1588875805       1588875805     205           -5.0         Villese
#
#       previous_rating  profile_id  rank  rating           steam_id  streak  \
# rank
# ...

# %%
leaderboard = leaderboard.drop(['clan','country','icon','previous_rating','steam_id'], axis=1)
leaderboard.head()
# Out:
#       drops  games  highest_rating  highest_streak  last_match  \
# rank
# 1         1    379          2321.0            19.0  1588793897
# 2        80   1073          2261.0            17.0  1588907728
# 3        13    435          2233.0            32.0  1588302652
# 4         5    455          2295.0            19.0  1588856609
# 5         2    546          2198.0            11.0  1588875805
#
#       last_match_time  losses  lowest_streak            name  profile_id  \
# rank
# 1          1588793897     110           -5.0        TheViper      196240
# 2          1588907728     334           -6.0      [aM]MbL40C      251265
# 3          1588302652     103           -4.0  Heresy | dogao      199170
# 4          1588856609     109           -4.0           Nicov      208393
# 5          1588875805     205           -5.0         Villese      208611
#
#       rank  rating  streak  wins
# rank
# 1        1    2321      19   269
# 2        2    2235      -1   739
# ...

# %%
leaderboard.isnull().sum().sum()
# Out:
# 6

# %%
leaderboard.isnull().sum()
# Out:
# drops              0
# games              0
# highest_rating     2
# highest_streak     2
# last_match         0
# last_match_time    0
# losses             0
# lowest_streak      2
# name               0
# profile_id         0
# rank               0
# rating             0
# streak             0
# wins               0
# dtype: int64

# %%
leaderboard.dropna().isnull().sum()
# Out:
# drops              0
# games              0
# highest_rating     0
# highest_streak     0
# last_match         0
# last_match_time    0
# losses             0
# lowest_streak      0
# name               0
# profile_id         0
# rank               0
# rating             0
# streak             0
# wins               0
# dtype: int64

# %%
leaderboard = leaderboard.dropna()
leaderboard.head()
# Out:
#       drops  games  highest_rating  highest_streak  last_match  \
# rank
# 1         1    379          2321.0            19.0  1588793897
# 2        80   1073          2261.0            17.0  1588907728
# 3        13    435          2233.0            32.0  1588302652
# 4         5    455          2295.0            19.0  1588856609
# 5         2    546          2198.0            11.0  1588875805
#
#       last_match_time  losses  lowest_streak            name  profile_id  \
# rank
# 1          1588793897     110           -5.0        TheViper      196240
# 2          1588907728     334           -6.0      [aM]MbL40C      251265
# 3          1588302652     103           -4.0  Heresy | dogao      199170
# 4          1588856609     109           -4.0           Nicov      208393
# 5          1588875805     205           -5.0         Villese      208611
#
#       rank  rating  streak  wins
# rank
# 1        1    2321      19   269
# 2        2    2235      -1   739
# ...

# %%
leaderboard.isnull().sum().sum()
# Out:
# 0

# %%
leaderboard.to_csv("leaderboard.csv")
